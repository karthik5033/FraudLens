# %%
# Update pip (optional but recommended)
# !pip install --upgrade pip

# Install HuggingFace Transformers + Datasets
# !pip install transformers datasets

# Install PyTorch (Colab usually has it preinstalled)
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu

# Install Sklearn for preprocessing + label encoding
# !pip install scikit-learn

# Install tqdm for progress bars
# !pip install tqdm

# Install Pandas + Numpy
# !pip install pandas numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...

# %%
# Colab: run this shell cell once
# !pip install --upgrade pip
# !pip install transformers datasets torch scikit-learn pandas tqdm accelerate

# %%
# !pip install --upgrade pip
# !pip install transformers accelerate onnx onnxruntime scikit-learn pandas tqdm --quiet

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

model_path = "/content/fraud_model_final"

model = AutoModelForSequenceClassification.from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)

print("Loaded model + tokenizer")
# Out:
# Loaded model + tokenizer

# %%
# !python -m transformers.onnx \
  --model=/content/fraud_model_final \
  --feature=sequence-classification \
  /content/fraud_model_final/
# Out:
# 2025-12-04 22:17:04.813919: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764886624.884294   17593 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764886624.906120   17593 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764886624.970683   17593 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import os

print(os.listdir("/content/fraud_model_final"))
# Out:
# ['vocab.txt', 'config.json', 'special_tokens_map.json', 'tokenizer.json', 'label_map.json', 'model.safetensors', 'tokenizer_config.json']

# %%
# !pip uninstall -y tensorflow tensorflow-cpu tensorflow-gpu flatbuffers
# Out:
# Found existing installation: tensorflow 2.19.0
# Uninstalling tensorflow-2.19.0:
#   Successfully uninstalled tensorflow-2.19.0
# WARNING: Skipping tensorflow-cpu as it is not installed.
# WARNING: Skipping tensorflow-gpu as it is not installed.
# Found existing installation: flatbuffers 2.0.7
# Uninstalling flatbuffers-2.0.7:
#   Successfully uninstalled flatbuffers-2.0.7

# %%
# !pip install onnx onnxruntime --quiet
# !pip install "transformers[onnx]" --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf2onnx 1.14.0 requires flatbuffers<3.0,>=1.12, but you have flatbuffers 25.9.23 which is incompatible.

# %%
# !pip uninstall -y tensorflow tensorflow-cpu tensorflow-gpu tf2onnx flatbuffers onnx onnxruntime
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# WARNING: Skipping tensorflow-cpu as it is not installed.
# WARNING: Skipping tensorflow-gpu as it is not installed.
# Found existing installation: tf2onnx 1.14.0
# Uninstalling tf2onnx-1.14.0:
#   Successfully uninstalled tf2onnx-1.14.0
# Found existing installation: flatbuffers 2.0.7
# Uninstalling flatbuffers-2.0.7:
#   Successfully uninstalled flatbuffers-2.0.7
# Found existing installation: onnx 1.20.0
# Uninstalling onnx-1.20.0:
#   Successfully uninstalled onnx-1.20.0
# Found existing installation: onnxruntime 1.23.2
# Uninstalling onnxruntime-1.23.2:
#   Successfully uninstalled onnxruntime-1.23.2

# %%
# !pip install flatbuffers==2.0 --quiet
# !pip install onnx==1.14.0 --quiet
# !pip install onnxruntime==1.15.0 --quiet
# !pip install "transformers[onnx]" --quiet
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   error: subprocess-exited-with-error
#
#   × Building wheel for onnx (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for onnx
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> onnx
# ERROR: Could not find a version that satisfies the requirement onnxruntime==1.15.0 (from versions: 1.17.0, 1.17.1, 1.17.3, 1.18.0, 1.18.1, 1.19.0, 1.19.2, 1.20.0, 1.20.1, 1.21.0, 1.21.1, 1.22.0, 1.22.1, 1.23.0, 1.23.1, 1.23.2, 1.24.0.dev20251031003)
# ERROR: No matching distribution found for onnxruntime==1.15.0

# %%
# !zip -r fraud_model_final.zip /content/fraud_model_final
# Out:
#   adding: content/fraud_model_final/ (stored 0%)
#   adding: content/fraud_model_final/vocab.txt (deflated 53%)
#   adding: content/fraud_model_final/config.json (deflated 51%)
#   adding: content/fraud_model_final/special_tokens_map.json (deflated 80%)
#   adding: content/fraud_model_final/tokenizer.json (deflated 71%)
#   adding: content/fraud_model_final/label_map.json (deflated 28%)
#   adding: content/fraud_model_final/model.safetensors (deflated 8%)
#   adding: content/fraud_model_final/tokenizer_config.json (deflated 73%)

# %%
from google.colab import files
files.download("fraud_model_final.zip")
